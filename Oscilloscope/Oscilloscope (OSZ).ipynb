# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import matplotlib.ticker as ticker
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %matplotlib inline

# %%
X = np.array([40, 100, 160, 240, 320, 560, 920, 400, 310, 120]).reshape((-1, 1))
Y = np.array([1.61, 1.50, 1.39, 1.25, 1.10, 0.69, 0, 0.92, 1.16, 1.48])

# %%
plt.figure(figsize=(9, 9))
plt.scatter(X, Y,  color='blue')
plt.xlabel("Zeit (ms)")
plt.ylabel("ln(U)")
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit (X, Y)

print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [-0.00182768]
# Intercept:  1.6893758931295257

# %%
plt.figure(figsize=(12, 12))
plt.scatter(X, Y,  color='blue')
plt.plot(X, regr.coef_[0]*X + regr.intercept_, '-r')
plt.grid()
plt.xlabel("Zeit (ms)")
plt.ylabel("ln(U)")
plt.title('Teilversuch 5')
# Out:
# Text(0.5, 1.0, 'Teilversuch 5')
